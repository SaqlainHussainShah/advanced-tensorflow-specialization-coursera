# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 950us/sample - loss: 232.7750 - y1_output_loss: 108.8082 - y2_output_loss: 121.9745 - y1_output_root_mean_squared_error: 10.4791 - y2_output_root_mean_squared_error: 11.0889 - val_loss: 27.7629 - val_y1_output_loss: 12.2150 - val_y2_output_loss: 14.8182 - val_y1_output_root_mean_squared_error: 3.5199 - val_y2_output_root_mean_squared_error: 3.9208
# Epoch 2/500
# 614/614 [==============================] - 0s 149us/sample - loss: 32.5259 - y1_output_loss: 13.2696 - y2_output_loss: 19.5114 - y1_output_root_mean_squared_error: 3.6130 - y2_output_root_mean_squared_error: 4.4128 - val_loss: 31.1321 - val_y1_output_loss: 10.8559 - val_y2_output_loss: 20.0507 - val_y1_output_root_mean_squared_error: 3.3327 - val_y2_output_root_mean_squared_error: 4.4750
# Epoch 3/500
# 614/614 [==============================] - 0s 135us/sample - loss: 26.7081 - y1_output_loss: 10.4618 - y2_output_loss: 16.0030 - y1_output_root_mean_squared_error: 3.2494 - y2_output_root_mean_squared_error: 4.0187 - val_loss: 18.8555 - val_y1_output_loss: 8.1139 - val_y2_output_loss: 10.2326 - val_y1_output_root_mean_squared_error: 2.8791 - val_y2_output_root_mean_squared_error: 3.2506
# Epoch 4/500
# 614/614 [==============================] - 0s 129us/sample - loss: 22.9474 - y1_output_loss: 9.2863 - y2_output_loss: 13.6173 - y1_output_root_mean_squared_error: 3.0449 - y2_output_root_mean_squared_error: 3.6981 - val_loss: 24.8665 - val_y1_output_loss: 9.2360 - val_y2_output_loss: 14.8716 - val_y1_output_root_mean_squared_error: 3.0747 - val_y2_output_root_mean_squared_error: 3.9259
# Epoch 5/500
# 614/614 [==============================] - 0s 134us/sample - loss: 27.0295 - y1_output_loss: 9.9015 - y2_output_loss: 17.0357 - y1_output_root_mean_squared_error: 3.1477 - y2_output_root_mean_squared_error: 4.1378 - val_loss: 16.0771 - val_y1_output_loss: 7.1622 - val_y2_output_loss: 8.6275 - val_y1_output_root_mean_squared_error: 2.7020 - val_y2_output_root_mean_squared_error: 2.9624
# Epoch 6/500
# 614/614 [==============================] - 0s 128us/sample - loss: 24.5899 - y1_output_loss: 8.9630 - y2_output_loss: 15.4963 - y1_output_root_mean_squared_error: 3.0013 - y2_output_root_mean_squared_error: 3.9474 - val_loss: 17.9098 - val_y1_output_loss: 7.6756 - val_y2_output_loss: 9.8083 - val_y1_output_root_mean_squared_error: 2.8002 - val_y2_output_root_mean_squared_error: 3.1731
# Epoch 7/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.6034 - y1_output_loss: 8.8437 - y2_output_loss: 13.6548 - y1_output_root_mean_squared_error: 2.9838 - y2_output_root_mean_squared_error: 3.7014 - val_loss: 28.8671 - val_y1_output_loss: 12.7184 - val_y2_output_loss: 16.3352 - val_y1_output_root_mean_squared_error: 3.5867 - val_y2_output_root_mean_squared_error: 4.0003
# Epoch 8/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.8938 - y1_output_loss: 8.3090 - y2_output_loss: 12.4806 - y1_output_root_mean_squared_error: 2.8924 - y2_output_root_mean_squared_error: 3.5395 - val_loss: 17.8681 - val_y1_output_loss: 8.0400 - val_y2_output_loss: 9.7554 - val_y1_output_root_mean_squared_error: 2.8603 - val_y2_output_root_mean_squared_error: 3.1123
# Epoch 9/500
# 614/614 [==============================] - 0s 124us/sample - loss: 24.7314 - y1_output_loss: 9.0421 - y2_output_loss: 15.6908 - y1_output_root_mean_squared_error: 3.0127 - y2_output_root_mean_squared_error: 3.9567 - val_loss: 19.8696 - val_y1_output_loss: 9.0325 - val_y2_output_loss: 11.0146 - val_y1_output_root_mean_squared_error: 3.0267 - val_y2_output_root_mean_squared_error: 3.2724
# Epoch 10/500
# 614/614 [==============================] - 0s 125us/sample - loss: 24.9249 - y1_output_loss: 9.1598 - y2_output_loss: 16.1986 - y1_output_root_mean_squared_error: 2.9981 - y2_output_root_mean_squared_error: 3.9920 - val_loss: 47.2454 - val_y1_output_loss: 13.0854 - val_y2_output_loss: 34.7357 - val_y1_output_root_mean_squared_error: 3.6331 - val_y2_output_root_mean_squared_error: 5.8349
# Epoch 11/500
# 614/614 [==============================] - 0s 125us/sample - loss: 26.7398 - y1_output_loss: 9.2620 - y2_output_loss: 17.2454 - y1_output_root_mean_squared_error: 3.0548 - y2_output_root_mean_squared_error: 4.1723 - val_loss: 18.7656 - val_y1_output_loss: 8.3967 - val_y2_output_loss: 10.6797 - val_y1_output_root_mean_squared_error: 2.9071 - val_y2_output_root_mean_squared_error: 3.2116
# Epoch 12/500
# 614/614 [==============================] - 0s 125us/sample - loss: 22.9494 - y1_output_loss: 8.5289 - y2_output_loss: 14.3837 - y1_output_root_mean_squared_error: 2.9150 - y2_output_root_mean_squared_error: 3.8016 - val_loss: 17.6475 - val_y1_output_loss: 8.0416 - val_y2_output_loss: 9.5106 - val_y1_output_root_mean_squared_error: 2.8536 - val_y2_output_root_mean_squared_error: 3.0829
# Epoch 13/500
# 614/614 [==============================] - 0s 125us/sample - loss: 20.9980 - y1_output_loss: 8.1010 - y2_output_loss: 12.8413 - y1_output_root_mean_squared_error: 2.8494 - y2_output_root_mean_squared_error: 3.5887 - val_loss: 17.6463 - val_y1_output_loss: 8.7596 - val_y2_output_loss: 8.8302 - val_y1_output_root_mean_squared_error: 2.9716 - val_y2_output_root_mean_squared_error: 2.9692
# Epoch 14/500
# 614/614 [==============================] - 0s 125us/sample - loss: 20.5605 - y1_output_loss: 8.1406 - y2_output_loss: 12.5777 - y1_output_root_mean_squared_error: 2.8273 - y2_output_root_mean_squared_error: 3.5450 - val_loss: 23.4017 - val_y1_output_loss: 7.8013 - val_y2_output_loss: 16.4869 - val_y1_output_root_mean_squared_error: 2.7845 - val_y2_output_root_mean_squared_error: 3.9558
# Epoch 15/500
# 614/614 [==============================] - 0s 128us/sample - loss: 22.1286 - y1_output_loss: 8.0432 - y2_output_loss: 13.9102 - y1_output_root_mean_squared_error: 2.8483 - y2_output_root_mean_squared_error: 3.7438 - val_loss: 17.3131 - val_y1_output_loss: 7.3936 - val_y2_output_loss: 9.7708 - val_y1_output_root_mean_squared_error: 2.7321 - val_y2_output_root_mean_squared_error: 3.1383
# Epoch 16/500
# 614/614 [==============================] - 0s 123us/sample - loss: 19.2049 - y1_output_loss: 7.3513 - y2_output_loss: 12.0032 - y1_output_root_mean_squared_error: 2.6953 - y2_output_root_mean_squared_error: 3.4555 - val_loss: 42.3223 - val_y1_output_loss: 10.7492 - val_y2_output_loss: 30.2874 - val_y1_output_root_mean_squared_error: 3.3097 - val_y2_output_root_mean_squared_error: 5.6008
# Epoch 17/500
# 614/614 [==============================] - 0s 123us/sample - loss: 18.4843 - y1_output_loss: 7.3887 - y2_output_loss: 11.1971 - y1_output_root_mean_squared_error: 2.6927 - y2_output_root_mean_squared_error: 3.3516 - val_loss: 16.2895 - val_y1_output_loss: 7.1275 - val_y2_output_loss: 9.7135 - val_y1_output_root_mean_squared_error: 2.6578 - val_y2_output_root_mean_squared_error: 3.0374
# Epoch 18/500
# 614/614 [==============================] - 0s 124us/sample - loss: 16.8627 - y1_output_loss: 6.6084 - y2_output_loss: 10.1177 - y1_output_root_mean_squared_error: 2.5798 - y2_output_root_mean_squared_error: 3.1949 - val_loss: 15.7827 - val_y1_output_loss: 6.8986 - val_y2_output_loss: 8.9107 - val_y1_output_root_mean_squared_error: 2.6408 - val_y2_output_root_mean_squared_error: 2.9680
# Epoch 19/500
# 614/614 [==============================] - 0s 135us/sample - loss: 18.4360 - y1_output_loss: 6.9341 - y2_output_loss: 11.4414 - y1_output_root_mean_squared_error: 2.6383 - y2_output_root_mean_squared_error: 3.3875 - val_loss: 21.3769 - val_y1_output_loss: 8.2950 - val_y2_output_loss: 13.7463 - val_y1_output_root_mean_squared_error: 2.8665 - val_y2_output_root_mean_squared_error: 3.6277
# Epoch 20/500
# 614/614 [==============================] - 0s 125us/sample - loss: 16.2778 - y1_output_loss: 6.3884 - y2_output_loss: 10.0738 - y1_output_root_mean_squared_error: 2.5148 - y2_output_root_mean_squared_error: 3.1550 - val_loss: 23.2509 - val_y1_output_loss: 8.7369 - val_y2_output_loss: 14.0805 - val_y1_output_root_mean_squared_error: 2.9643 - val_y2_output_root_mean_squared_error: 3.8032
# Epoch 21/500
# 614/614 [==============================] - 0s 125us/sample - loss: 20.6695 - y1_output_loss: 7.8175 - y2_output_loss: 12.8962 - y1_output_root_mean_squared_error: 2.7726 - y2_output_root_mean_squared_error: 3.6031 - val_loss: 20.5103 - val_y1_output_loss: 9.7896 - val_y2_output_loss: 11.5171 - val_y1_output_root_mean_squared_error: 3.1029 - val_y2_output_root_mean_squared_error: 3.2988
# Epoch 22/500
# 614/614 [==============================] - 0s 127us/sample - loss: 15.4964 - y1_output_loss: 6.2850 - y2_output_loss: 9.1947 - y1_output_root_mean_squared_error: 2.5147 - y2_output_root_mean_squared_error: 3.0286 - val_loss: 18.2964 - val_y1_output_loss: 7.7725 - val_y2_output_loss: 10.9439 - val_y1_output_root_mean_squared_error: 2.7903 - val_y2_output_root_mean_squared_error: 3.2420
# Epoch 23/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.1955 - y1_output_loss: 5.7588 - y2_output_loss: 10.3454 - y1_output_root_mean_squared_error: 2.4065 - y2_output_root_mean_squared_error: 3.2256 - val_loss: 13.8827 - val_y1_output_loss: 5.9405 - val_y2_output_loss: 8.3630 - val_y1_output_root_mean_squared_error: 2.4153 - val_y2_output_root_mean_squared_error: 2.8371
# Epoch 24/500
# 614/614 [==============================] - 0s 125us/sample - loss: 16.4595 - y1_output_loss: 6.3306 - y2_output_loss: 10.0282 - y1_output_root_mean_squared_error: 2.5256 - y2_output_root_mean_squared_error: 3.1751 - val_loss: 12.2390 - val_y1_output_loss: 5.6074 - val_y2_output_loss: 6.8463 - val_y1_output_root_mean_squared_error: 2.3491 - val_y2_output_root_mean_squared_error: 2.5924
# Epoch 25/500
# 614/614 [==============================] - 0s 126us/sample - loss: 15.6452 - y1_output_loss: 5.5655 - y2_output_loss: 9.9426 - y1_output_root_mean_squared_error: 2.3694 - y2_output_root_mean_squared_error: 3.1672 - val_loss: 14.2002 - val_y1_output_loss: 5.8554 - val_y2_output_loss: 8.3773 - val_y1_output_root_mean_squared_error: 2.4075 - val_y2_output_root_mean_squared_error: 2.8990
# Epoch 26/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.7281 - y1_output_loss: 5.4791 - y2_output_loss: 9.2750 - y1_output_root_mean_squared_error: 2.3481 - y2_output_root_mean_squared_error: 3.0356 - val_loss: 32.6853 - val_y1_output_loss: 8.6726 - val_y2_output_loss: 24.9372 - val_y1_output_root_mean_squared_error: 2.9268 - val_y2_output_root_mean_squared_error: 4.9112
# Epoch 27/500
# 614/614 [==============================] - 0s 126us/sample - loss: 15.1759 - y1_output_loss: 5.6558 - y2_output_loss: 9.4718 - y1_output_root_mean_squared_error: 2.3786 - y2_output_root_mean_squared_error: 3.0852 - val_loss: 15.5875 - val_y1_output_loss: 6.0899 - val_y2_output_loss: 9.4261 - val_y1_output_root_mean_squared_error: 2.4375 - val_y2_output_root_mean_squared_error: 3.1058
# Epoch 28/500
# 614/614 [==============================] - 0s 125us/sample - loss: 19.9209 - y1_output_loss: 6.6258 - y2_output_loss: 13.4544 - y1_output_root_mean_squared_error: 2.5496 - y2_output_root_mean_squared_error: 3.6634 - val_loss: 33.0429 - val_y1_output_loss: 10.2773 - val_y2_output_loss: 22.0571 - val_y1_output_root_mean_squared_error: 3.2067 - val_y2_output_root_mean_squared_error: 4.7707
# Epoch 29/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.6104 - y1_output_loss: 5.0413 - y2_output_loss: 8.5184 - y1_output_root_mean_squared_error: 2.2460 - y2_output_root_mean_squared_error: 2.9267 - val_loss: 21.2423 - val_y1_output_loss: 9.0121 - val_y2_output_loss: 12.9398 - val_y1_output_root_mean_squared_error: 2.9840 - val_y2_output_root_mean_squared_error: 3.5125
# Epoch 30/500
# 614/614 [==============================] - 0s 127us/sample - loss: 13.7807 - y1_output_loss: 4.9425 - y2_output_loss: 8.7749 - y1_output_root_mean_squared_error: 2.2327 - y2_output_root_mean_squared_error: 2.9658 - val_loss: 12.7374 - val_y1_output_loss: 4.8857 - val_y2_output_loss: 8.3397 - val_y1_output_root_mean_squared_error: 2.1903 - val_y2_output_root_mean_squared_error: 2.8178
# Epoch 31/500
# 614/614 [==============================] - 0s 137us/sample - loss: 13.1048 - y1_output_loss: 4.5938 - y2_output_loss: 8.5613 - y1_output_root_mean_squared_error: 2.1384 - y2_output_root_mean_squared_error: 2.9209 - val_loss: 23.3411 - val_y1_output_loss: 6.5855 - val_y2_output_loss: 16.2572 - val_y1_output_root_mean_squared_error: 2.5625 - val_y2_output_root_mean_squared_error: 4.0957
# Epoch 32/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.9123 - y1_output_loss: 4.9349 - y2_output_loss: 9.0367 - y1_output_root_mean_squared_error: 2.2268 - y2_output_root_mean_squared_error: 2.9923 - val_loss: 14.0450 - val_y1_output_loss: 5.2431 - val_y2_output_loss: 9.1360 - val_y1_output_root_mean_squared_error: 2.2734 - val_y2_output_root_mean_squared_error: 2.9794
# Epoch 33/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.7260 - y1_output_loss: 4.1255 - y2_output_loss: 6.5679 - y1_output_root_mean_squared_error: 2.0321 - y2_output_root_mean_squared_error: 2.5684 - val_loss: 10.7523 - val_y1_output_loss: 4.5963 - val_y2_output_loss: 6.3628 - val_y1_output_root_mean_squared_error: 2.1105 - val_y2_output_root_mean_squared_error: 2.5096
# Epoch 34/500
# 614/614 [==============================] - 0s 126us/sample - loss: 12.1316 - y1_output_loss: 4.2815 - y2_output_loss: 7.7924 - y1_output_root_mean_squared_error: 2.0766 - y2_output_root_mean_squared_error: 2.7963 - val_loss: 11.0730 - val_y1_output_loss: 4.9058 - val_y2_output_loss: 6.3828 - val_y1_output_root_mean_squared_error: 2.1986 - val_y2_output_root_mean_squared_error: 2.4978
# Epoch 35/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.5728 - y1_output_loss: 4.3366 - y2_output_loss: 7.4071 - y1_output_root_mean_squared_error: 2.0589 - y2_output_root_mean_squared_error: 2.7081 - val_loss: 30.5926 - val_y1_output_loss: 10.9631 - val_y2_output_loss: 19.1015 - val_y1_output_root_mean_squared_error: 3.3037 - val_y2_output_root_mean_squared_error: 4.4360
# Epoch 36/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.6683 - y1_output_loss: 3.7446 - y2_output_loss: 6.8647 - y1_output_root_mean_squared_error: 1.9412 - y2_output_root_mean_squared_error: 2.6268 - val_loss: 13.3812 - val_y1_output_loss: 4.7758 - val_y2_output_loss: 8.9724 - val_y1_output_root_mean_squared_error: 2.1673 - val_y2_output_root_mean_squared_error: 2.9468
# Epoch 37/500
# 614/614 [==============================] - 0s 125us/sample - loss: 12.4086 - y1_output_loss: 4.5201 - y2_output_loss: 7.7937 - y1_output_root_mean_squared_error: 2.1325 - y2_output_root_mean_squared_error: 2.8038 - val_loss: 13.0861 - val_y1_output_loss: 5.7446 - val_y2_output_loss: 7.7440 - val_y1_output_root_mean_squared_error: 2.3795 - val_y2_output_root_mean_squared_error: 2.7247
# Epoch 38/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.1620 - y1_output_loss: 3.5888 - y2_output_loss: 6.6659 - y1_output_root_mean_squared_error: 1.8851 - y2_output_root_mean_squared_error: 2.5707 - val_loss: 10.9213 - val_y1_output_loss: 5.1800 - val_y2_output_loss: 5.8011 - val_y1_output_root_mean_squared_error: 2.2598 - val_y2_output_root_mean_squared_error: 2.4113
# Epoch 39/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.6967 - y1_output_loss: 3.6650 - y2_output_loss: 6.9699 - y1_output_root_mean_squared_error: 1.9202 - y2_output_root_mean_squared_error: 2.6476 - val_loss: 10.9899 - val_y1_output_loss: 4.0040 - val_y2_output_loss: 6.9331 - val_y1_output_root_mean_squared_error: 1.9871 - val_y2_output_root_mean_squared_error: 2.6535
# Epoch 40/500
# 614/614 [==============================] - 0s 125us/sample - loss: 10.7953 - y1_output_loss: 3.8391 - y2_output_loss: 6.9254 - y1_output_root_mean_squared_error: 1.9615 - y2_output_root_mean_squared_error: 2.6358 - val_loss: 8.8704 - val_y1_output_loss: 3.8169 - val_y2_output_loss: 5.1268 - val_y1_output_root_mean_squared_error: 1.9306 - val_y2_output_root_mean_squared_error: 2.2678
# Epoch 41/500
# 614/614 [==============================] - 0s 125us/sample - loss: 12.1697 - y1_output_loss: 3.8480 - y2_output_loss: 8.3076 - y1_output_root_mean_squared_error: 1.9562 - y2_output_root_mean_squared_error: 2.8884 - val_loss: 8.6251 - val_y1_output_loss: 3.7176 - val_y2_output_loss: 5.2146 - val_y1_output_root_mean_squared_error: 1.9063 - val_y2_output_root_mean_squared_error: 2.2341
# Epoch 42/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.6682 - y1_output_loss: 3.9479 - y2_output_loss: 8.6779 - y1_output_root_mean_squared_error: 1.9865 - y2_output_root_mean_squared_error: 2.9533 - val_loss: 7.9674 - val_y1_output_loss: 3.0928 - val_y2_output_loss: 4.9095 - val_y1_output_root_mean_squared_error: 1.7345 - val_y2_output_root_mean_squared_error: 2.2268
# Epoch 43/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.4674 - y1_output_loss: 3.6968 - y2_output_loss: 7.6701 - y1_output_root_mean_squared_error: 1.9309 - y2_output_root_mean_squared_error: 2.7819 - val_loss: 7.9355 - val_y1_output_loss: 3.2004 - val_y2_output_loss: 4.8967 - val_y1_output_root_mean_squared_error: 1.7628 - val_y2_output_root_mean_squared_error: 2.1973
# Epoch 44/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.5717 - y1_output_loss: 2.6903 - y2_output_loss: 4.8693 - y1_output_root_mean_squared_error: 1.6466 - y2_output_root_mean_squared_error: 2.2047 - val_loss: 7.2890 - val_y1_output_loss: 3.1757 - val_y2_output_loss: 4.2344 - val_y1_output_root_mean_squared_error: 1.7615 - val_y2_output_root_mean_squared_error: 2.0460
# Epoch 45/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.9999 - y1_output_loss: 2.9303 - y2_output_loss: 6.0928 - y1_output_root_mean_squared_error: 1.7089 - y2_output_root_mean_squared_error: 2.4657 - val_loss: 28.5935 - val_y1_output_loss: 6.6621 - val_y2_output_loss: 22.5675 - val_y1_output_root_mean_squared_error: 2.5679 - val_y2_output_root_mean_squared_error: 4.6904
# Epoch 46/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.7369 - y1_output_loss: 3.0448 - y2_output_loss: 6.7827 - y1_output_root_mean_squared_error: 1.7362 - y2_output_root_mean_squared_error: 2.5928 - val_loss: 10.8455 - val_y1_output_loss: 3.5229 - val_y2_output_loss: 7.2388 - val_y1_output_root_mean_squared_error: 1.8583 - val_y2_output_root_mean_squared_error: 2.7189
# Epoch 47/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.3509 - y1_output_loss: 2.9795 - y2_output_loss: 6.4179 - y1_output_root_mean_squared_error: 1.7154 - y2_output_root_mean_squared_error: 2.5315 - val_loss: 9.2961 - val_y1_output_loss: 3.2153 - val_y2_output_loss: 6.4656 - val_y1_output_root_mean_squared_error: 1.7710 - val_y2_output_root_mean_squared_error: 2.4819
# Epoch 48/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.7832 - y1_output_loss: 2.7493 - y2_output_loss: 6.0505 - y1_output_root_mean_squared_error: 1.6604 - y2_output_root_mean_squared_error: 2.4548 - val_loss: 11.6918 - val_y1_output_loss: 3.5003 - val_y2_output_loss: 8.5947 - val_y1_output_root_mean_squared_error: 1.8551 - val_y2_output_root_mean_squared_error: 2.8723
# Epoch 49/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.8505 - y1_output_loss: 2.4422 - y2_output_loss: 5.3445 - y1_output_root_mean_squared_error: 1.5701 - y2_output_root_mean_squared_error: 2.3207 - val_loss: 6.8182 - val_y1_output_loss: 2.7800 - val_y2_output_loss: 4.1106 - val_y1_output_root_mean_squared_error: 1.6322 - val_y2_output_root_mean_squared_error: 2.0381
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.0457 - y1_output_loss: 2.5539 - y2_output_loss: 5.5020 - y1_output_root_mean_squared_error: 1.5956 - y2_output_root_mean_squared_error: 2.3451 - val_loss: 18.0343 - val_y1_output_loss: 6.8711 - val_y2_output_loss: 10.7976 - val_y1_output_root_mean_squared_error: 2.6400 - val_y2_output_root_mean_squared_error: 3.3264
# Epoch 51/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.2393 - y1_output_loss: 2.9349 - y2_output_loss: 6.3426 - y1_output_root_mean_squared_error: 1.7171 - y2_output_root_mean_squared_error: 2.5081 - val_loss: 6.9909 - val_y1_output_loss: 2.8461 - val_y2_output_loss: 4.1695 - val_y1_output_root_mean_squared_error: 1.6633 - val_y2_output_root_mean_squared_error: 2.0553
# Epoch 52/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.2910 - y1_output_loss: 2.5427 - y2_output_loss: 5.8421 - y1_output_root_mean_squared_error: 1.5895 - y2_output_root_mean_squared_error: 2.4009 - val_loss: 29.3871 - val_y1_output_loss: 7.8623 - val_y2_output_loss: 20.6693 - val_y1_output_root_mean_squared_error: 2.8249 - val_y2_output_root_mean_squared_error: 4.6268
# Epoch 53/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.3484 - y1_output_loss: 2.7755 - y2_output_loss: 6.6949 - y1_output_root_mean_squared_error: 1.6656 - y2_output_root_mean_squared_error: 2.5640 - val_loss: 34.3963 - val_y1_output_loss: 6.6927 - val_y2_output_loss: 28.2810 - val_y1_output_root_mean_squared_error: 2.5896 - val_y2_output_root_mean_squared_error: 5.2621
# Epoch 54/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.5774 - y1_output_loss: 2.4599 - y2_output_loss: 5.0714 - y1_output_root_mean_squared_error: 1.5679 - y2_output_root_mean_squared_error: 2.2626 - val_loss: 5.8230 - val_y1_output_loss: 2.1189 - val_y2_output_loss: 3.7186 - val_y1_output_root_mean_squared_error: 1.4393 - val_y2_output_root_mean_squared_error: 1.9369
# Epoch 55/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.7305 - y1_output_loss: 3.3940 - y2_output_loss: 7.2427 - y1_output_root_mean_squared_error: 1.8500 - y2_output_root_mean_squared_error: 2.7033 - val_loss: 5.8142 - val_y1_output_loss: 2.1992 - val_y2_output_loss: 3.6269 - val_y1_output_root_mean_squared_error: 1.4690 - val_y2_output_root_mean_squared_error: 1.9121
# Epoch 56/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.3659 - y1_output_loss: 2.4098 - y2_output_loss: 5.9052 - y1_output_root_mean_squared_error: 1.5566 - y2_output_root_mean_squared_error: 2.4378 - val_loss: 9.1706 - val_y1_output_loss: 3.4721 - val_y2_output_loss: 5.6827 - val_y1_output_root_mean_squared_error: 1.8342 - val_y2_output_root_mean_squared_error: 2.4096
# Epoch 57/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.2733 - y1_output_loss: 2.5869 - y2_output_loss: 5.6438 - y1_output_root_mean_squared_error: 1.6146 - y2_output_root_mean_squared_error: 2.3804 - val_loss: 6.8868 - val_y1_output_loss: 2.8423 - val_y2_output_loss: 4.0161 - val_y1_output_root_mean_squared_error: 1.6785 - val_y2_output_root_mean_squared_error: 2.0173
# Epoch 58/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.6967 - y1_output_loss: 2.0326 - y2_output_loss: 4.6587 - y1_output_root_mean_squared_error: 1.4272 - y2_output_root_mean_squared_error: 2.1586 - val_loss: 5.9382 - val_y1_output_loss: 2.0309 - val_y2_output_loss: 4.0567 - val_y1_output_root_mean_squared_error: 1.4163 - val_y2_output_root_mean_squared_error: 1.9830
# Epoch 59/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.7157 - y1_output_loss: 2.1290 - y2_output_loss: 4.6103 - y1_output_root_mean_squared_error: 1.4447 - y2_output_root_mean_squared_error: 2.1514 - val_loss: 5.6019 - val_y1_output_loss: 1.8938 - val_y2_output_loss: 3.6832 - val_y1_output_root_mean_squared_error: 1.3641 - val_y2_output_root_mean_squared_error: 1.9342
# Epoch 60/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.1795 - y1_output_loss: 2.0206 - y2_output_loss: 5.1553 - y1_output_root_mean_squared_error: 1.4219 - y2_output_root_mean_squared_error: 2.2711 - val_loss: 11.7017 - val_y1_output_loss: 2.4837 - val_y2_output_loss: 9.5659 - val_y1_output_root_mean_squared_error: 1.5710 - val_y2_output_root_mean_squared_error: 3.0387
# Epoch 61/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.9251 - y1_output_loss: 2.4849 - y2_output_loss: 6.3668 - y1_output_root_mean_squared_error: 1.5810 - y2_output_root_mean_squared_error: 2.5349 - val_loss: 5.3011 - val_y1_output_loss: 2.1690 - val_y2_output_loss: 3.1856 - val_y1_output_root_mean_squared_error: 1.4612 - val_y2_output_root_mean_squared_error: 1.7794
# Epoch 62/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.7975 - y1_output_loss: 2.0058 - y2_output_loss: 4.7779 - y1_output_root_mean_squared_error: 1.4219 - y2_output_root_mean_squared_error: 2.1853 - val_loss: 6.7048 - val_y1_output_loss: 1.8153 - val_y2_output_loss: 4.7639 - val_y1_output_root_mean_squared_error: 1.3360 - val_y2_output_root_mean_squared_error: 2.2181
# Epoch 63/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.0883 - y1_output_loss: 2.0455 - y2_output_loss: 5.0146 - y1_output_root_mean_squared_error: 1.4275 - y2_output_root_mean_squared_error: 2.2474 - val_loss: 5.8743 - val_y1_output_loss: 2.1014 - val_y2_output_loss: 3.7290 - val_y1_output_root_mean_squared_error: 1.4408 - val_y2_output_root_mean_squared_error: 1.9489
# Epoch 64/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.7081 - y1_output_loss: 1.7220 - y2_output_loss: 3.9693 - y1_output_root_mean_squared_error: 1.3100 - y2_output_root_mean_squared_error: 1.9980 - val_loss: 4.5375 - val_y1_output_loss: 1.6884 - val_y2_output_loss: 2.9255 - val_y1_output_root_mean_squared_error: 1.2889 - val_y2_output_root_mean_squared_error: 1.6960
# Epoch 65/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.7376 - y1_output_loss: 2.9099 - y2_output_loss: 7.1683 - y1_output_root_mean_squared_error: 1.6930 - y2_output_root_mean_squared_error: 2.6213 - val_loss: 44.6104 - val_y1_output_loss: 9.9372 - val_y2_output_loss: 33.1591 - val_y1_output_root_mean_squared_error: 3.2010 - val_y2_output_root_mean_squared_error: 5.8621
# Epoch 66/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.4343 - y1_output_loss: 2.3446 - y2_output_loss: 5.3322 - y1_output_root_mean_squared_error: 1.5036 - y2_output_root_mean_squared_error: 2.2745 - val_loss: 48.5956 - val_y1_output_loss: 17.7374 - val_y2_output_loss: 29.4324 - val_y1_output_root_mean_squared_error: 4.2577 - val_y2_output_root_mean_squared_error: 5.5197
# Epoch 67/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.5595 - y1_output_loss: 2.9518 - y2_output_loss: 5.5377 - y1_output_root_mean_squared_error: 1.7250 - y2_output_root_mean_squared_error: 2.3630 - val_loss: 7.0287 - val_y1_output_loss: 1.9060 - val_y2_output_loss: 5.3292 - val_y1_output_root_mean_squared_error: 1.3789 - val_y2_output_root_mean_squared_error: 2.2644
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.8768 - y1_output_loss: 1.7675 - y2_output_loss: 4.0600 - y1_output_root_mean_squared_error: 1.3348 - y2_output_root_mean_squared_error: 2.0236 - val_loss: 4.8496 - val_y1_output_loss: 1.6540 - val_y2_output_loss: 3.3056 - val_y1_output_root_mean_squared_error: 1.2792 - val_y2_output_root_mean_squared_error: 1.7926
# Epoch 69/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5261 - y1_output_loss: 1.6117 - y2_output_loss: 3.9408 - y1_output_root_mean_squared_error: 1.2693 - y2_output_root_mean_squared_error: 1.9786 - val_loss: 6.3186 - val_y1_output_loss: 1.7054 - val_y2_output_loss: 4.4984 - val_y1_output_root_mean_squared_error: 1.3057 - val_y2_output_root_mean_squared_error: 2.1480
# Epoch 70/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.7592 - y1_output_loss: 1.8108 - y2_output_loss: 3.9330 - y1_output_root_mean_squared_error: 1.3446 - y2_output_root_mean_squared_error: 1.9878 - val_loss: 7.6927 - val_y1_output_loss: 2.2373 - val_y2_output_loss: 5.6500 - val_y1_output_root_mean_squared_error: 1.4982 - val_y2_output_root_mean_squared_error: 2.3341
# Epoch 71/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.8248 - y1_output_loss: 1.4434 - y2_output_loss: 3.3897 - y1_output_root_mean_squared_error: 1.2049 - y2_output_root_mean_squared_error: 1.8366 - val_loss: 5.2997 - val_y1_output_loss: 1.7885 - val_y2_output_loss: 3.4763 - val_y1_output_root_mean_squared_error: 1.3326 - val_y2_output_root_mean_squared_error: 1.8772
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.4324 - y1_output_loss: 1.5962 - y2_output_loss: 3.8349 - y1_output_root_mean_squared_error: 1.2670 - y2_output_root_mean_squared_error: 1.9563 - val_loss: 4.3695 - val_y1_output_loss: 1.4455 - val_y2_output_loss: 2.9747 - val_y1_output_root_mean_squared_error: 1.1994 - val_y2_output_root_mean_squared_error: 1.7120
# Epoch 73/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.9710 - y1_output_loss: 1.7029 - y2_output_loss: 4.2600 - y1_output_root_mean_squared_error: 1.3059 - y2_output_root_mean_squared_error: 2.0654 - val_loss: 6.9567 - val_y1_output_loss: 2.3558 - val_y2_output_loss: 4.5038 - val_y1_output_root_mean_squared_error: 1.5222 - val_y2_output_root_mean_squared_error: 2.1540
# Epoch 74/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6904 - y1_output_loss: 1.4329 - y2_output_loss: 3.2313 - y1_output_root_mean_squared_error: 1.1990 - y2_output_root_mean_squared_error: 1.8036 - val_loss: 6.4155 - val_y1_output_loss: 1.6218 - val_y2_output_loss: 4.9513 - val_y1_output_root_mean_squared_error: 1.2706 - val_y2_output_root_mean_squared_error: 2.1911
# Epoch 75/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.7059 - y1_output_loss: 1.5851 - y2_output_loss: 4.0830 - y1_output_root_mean_squared_error: 1.2631 - y2_output_root_mean_squared_error: 2.0274 - val_loss: 4.1990 - val_y1_output_loss: 1.3643 - val_y2_output_loss: 2.8686 - val_y1_output_root_mean_squared_error: 1.1612 - val_y2_output_root_mean_squared_error: 1.6884
# Epoch 76/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.9002 - y1_output_loss: 1.3446 - y2_output_loss: 3.6253 - y1_output_root_mean_squared_error: 1.1618 - y2_output_root_mean_squared_error: 1.8843 - val_loss: 18.2461 - val_y1_output_loss: 2.5998 - val_y2_output_loss: 15.8994 - val_y1_output_root_mean_squared_error: 1.6196 - val_y2_output_root_mean_squared_error: 3.9526
# Epoch 77/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.9256 - y1_output_loss: 1.5924 - y2_output_loss: 4.3048 - y1_output_root_mean_squared_error: 1.2635 - y2_output_root_mean_squared_error: 2.0807 - val_loss: 5.7512 - val_y1_output_loss: 1.7781 - val_y2_output_loss: 4.2537 - val_y1_output_root_mean_squared_error: 1.3256 - val_y2_output_root_mean_squared_error: 1.9985
# Epoch 78/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.0468 - y1_output_loss: 1.6692 - y2_output_loss: 4.3872 - y1_output_root_mean_squared_error: 1.2917 - y2_output_root_mean_squared_error: 2.0924 - val_loss: 4.5702 - val_y1_output_loss: 1.5732 - val_y2_output_loss: 3.1242 - val_y1_output_root_mean_squared_error: 1.2576 - val_y2_output_root_mean_squared_error: 1.7287
# Epoch 79/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.0583 - y1_output_loss: 1.7754 - y2_output_loss: 4.2954 - y1_output_root_mean_squared_error: 1.3303 - y2_output_root_mean_squared_error: 2.0709 - val_loss: 7.7895 - val_y1_output_loss: 2.0166 - val_y2_output_loss: 5.8750 - val_y1_output_root_mean_squared_error: 1.4349 - val_y2_output_root_mean_squared_error: 2.3938
# Epoch 80/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.2848 - y1_output_loss: 1.3832 - y2_output_loss: 3.8803 - y1_output_root_mean_squared_error: 1.1808 - y2_output_root_mean_squared_error: 1.9724 - val_loss: 3.6989 - val_y1_output_loss: 1.0358 - val_y2_output_loss: 2.6695 - val_y1_output_root_mean_squared_error: 1.0111 - val_y2_output_root_mean_squared_error: 1.6360
# Epoch 81/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.4032 - y1_output_loss: 1.4457 - y2_output_loss: 3.9451 - y1_output_root_mean_squared_error: 1.2075 - y2_output_root_mean_squared_error: 1.9863 - val_loss: 3.9795 - val_y1_output_loss: 1.2769 - val_y2_output_loss: 2.7533 - val_y1_output_root_mean_squared_error: 1.1346 - val_y2_output_root_mean_squared_error: 1.6408
# Epoch 82/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.9993 - y1_output_loss: 1.3211 - y2_output_loss: 3.6979 - y1_output_root_mean_squared_error: 1.1544 - y2_output_root_mean_squared_error: 1.9149 - val_loss: 3.7853 - val_y1_output_loss: 1.2356 - val_y2_output_loss: 2.6086 - val_y1_output_root_mean_squared_error: 1.1198 - val_y2_output_root_mean_squared_error: 1.5910
# Epoch 83/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.5791 - y1_output_loss: 1.1692 - y2_output_loss: 3.3890 - y1_output_root_mean_squared_error: 1.0855 - y2_output_root_mean_squared_error: 1.8441 - val_loss: 4.9299 - val_y1_output_loss: 1.0590 - val_y2_output_loss: 3.7459 - val_y1_output_root_mean_squared_error: 1.0294 - val_y2_output_root_mean_squared_error: 1.9673
# Epoch 84/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6302 - y1_output_loss: 0.8747 - y2_output_loss: 2.7748 - y1_output_root_mean_squared_error: 0.9345 - y2_output_root_mean_squared_error: 1.6604 - val_loss: 3.7490 - val_y1_output_loss: 1.3646 - val_y2_output_loss: 2.5047 - val_y1_output_root_mean_squared_error: 1.1761 - val_y2_output_root_mean_squared_error: 1.5381
# Epoch 85/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.6530 - y1_output_loss: 0.9074 - y2_output_loss: 2.7352 - y1_output_root_mean_squared_error: 0.9513 - y2_output_root_mean_squared_error: 1.6577 - val_loss: 3.6719 - val_y1_output_loss: 1.2107 - val_y2_output_loss: 2.5846 - val_y1_output_root_mean_squared_error: 1.1111 - val_y2_output_root_mean_squared_error: 1.5612
# Epoch 86/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5866 - y1_output_loss: 0.7862 - y2_output_loss: 2.7770 - y1_output_root_mean_squared_error: 0.8904 - y2_output_root_mean_squared_error: 1.6715 - val_loss: 5.1681 - val_y1_output_loss: 1.4176 - val_y2_output_loss: 3.8340 - val_y1_output_root_mean_squared_error: 1.2053 - val_y2_output_root_mean_squared_error: 1.9275
# Epoch 87/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.5467 - y1_output_loss: 1.1035 - y2_output_loss: 3.4012 - y1_output_root_mean_squared_error: 1.0551 - y2_output_root_mean_squared_error: 1.8529 - val_loss: 2.8649 - val_y1_output_loss: 0.8700 - val_y2_output_loss: 1.9949 - val_y1_output_root_mean_squared_error: 0.9363 - val_y2_output_root_mean_squared_error: 1.4101
# Epoch 88/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.1266 - y1_output_loss: 1.0327 - y2_output_loss: 3.0785 - y1_output_root_mean_squared_error: 1.0141 - y2_output_root_mean_squared_error: 1.7601 - val_loss: 5.3252 - val_y1_output_loss: 0.9903 - val_y2_output_loss: 4.4623 - val_y1_output_root_mean_squared_error: 1.0062 - val_y2_output_root_mean_squared_error: 2.0767
# Epoch 89/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.3171 - y1_output_loss: 1.2960 - y2_output_loss: 3.9824 - y1_output_root_mean_squared_error: 1.1428 - y2_output_root_mean_squared_error: 2.0028 - val_loss: 3.5435 - val_y1_output_loss: 1.0745 - val_y2_output_loss: 2.5269 - val_y1_output_root_mean_squared_error: 1.0502 - val_y2_output_root_mean_squared_error: 1.5622
# Epoch 90/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8627 - y1_output_loss: 1.1307 - y2_output_loss: 3.7134 - y1_output_root_mean_squared_error: 1.0650 - y2_output_root_mean_squared_error: 1.9309 - val_loss: 4.0579 - val_y1_output_loss: 0.7993 - val_y2_output_loss: 3.1711 - val_y1_output_root_mean_squared_error: 0.9061 - val_y2_output_root_mean_squared_error: 1.7992
# Epoch 91/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.5581 - y1_output_loss: 0.8716 - y2_output_loss: 2.7388 - y1_output_root_mean_squared_error: 0.9349 - y2_output_root_mean_squared_error: 1.6383 - val_loss: 4.8298 - val_y1_output_loss: 0.8816 - val_y2_output_loss: 3.8090 - val_y1_output_root_mean_squared_error: 0.9431 - val_y2_output_root_mean_squared_error: 1.9850
# Epoch 92/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.1788 - y1_output_loss: 0.6869 - y2_output_loss: 2.4894 - y1_output_root_mean_squared_error: 0.8261 - y2_output_root_mean_squared_error: 1.5800 - val_loss: 2.5196 - val_y1_output_loss: 0.7405 - val_y2_output_loss: 1.8069 - val_y1_output_root_mean_squared_error: 0.8679 - val_y2_output_root_mean_squared_error: 1.3291
# Epoch 93/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8593 - y1_output_loss: 1.2835 - y2_output_loss: 3.5508 - y1_output_root_mean_squared_error: 1.1370 - y2_output_root_mean_squared_error: 1.8885 - val_loss: 3.6309 - val_y1_output_loss: 0.7657 - val_y2_output_loss: 2.9957 - val_y1_output_root_mean_squared_error: 0.8843 - val_y2_output_root_mean_squared_error: 1.6879
# Epoch 94/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.0004 - y1_output_loss: 1.2784 - y2_output_loss: 3.7286 - y1_output_root_mean_squared_error: 1.1289 - y2_output_root_mean_squared_error: 1.9302 - val_loss: 6.8933 - val_y1_output_loss: 1.9228 - val_y2_output_loss: 5.1268 - val_y1_output_root_mean_squared_error: 1.4034 - val_y2_output_root_mean_squared_error: 2.2190
# Epoch 95/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.8380 - y1_output_loss: 1.2097 - y2_output_loss: 3.6251 - y1_output_root_mean_squared_error: 1.0994 - y2_output_root_mean_squared_error: 1.9051 - val_loss: 3.1618 - val_y1_output_loss: 0.6957 - val_y2_output_loss: 2.6018 - val_y1_output_root_mean_squared_error: 0.8467 - val_y2_output_root_mean_squared_error: 1.5636
# Epoch 96/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.5927 - y1_output_loss: 0.5590 - y2_output_loss: 2.0149 - y1_output_root_mean_squared_error: 0.7490 - y2_output_root_mean_squared_error: 1.4254 - val_loss: 2.6931 - val_y1_output_loss: 0.7648 - val_y2_output_loss: 1.9146 - val_y1_output_root_mean_squared_error: 0.8819 - val_y2_output_root_mean_squared_error: 1.3840
# Epoch 97/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2495 - y1_output_loss: 0.7060 - y2_output_loss: 2.6041 - y1_output_root_mean_squared_error: 0.8394 - y2_output_root_mean_squared_error: 1.5953 - val_loss: 2.5778 - val_y1_output_loss: 0.6445 - val_y2_output_loss: 1.9384 - val_y1_output_root_mean_squared_error: 0.8159 - val_y2_output_root_mean_squared_error: 1.3828
# Epoch 98/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0612 - y1_output_loss: 0.6613 - y2_output_loss: 2.4051 - y1_output_root_mean_squared_error: 0.8024 - y2_output_root_mean_squared_error: 1.5548 - val_loss: 2.9394 - val_y1_output_loss: 0.8976 - val_y2_output_loss: 2.0161 - val_y1_output_root_mean_squared_error: 0.9444 - val_y2_output_root_mean_squared_error: 1.4309
# Epoch 99/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.6841 - y1_output_loss: 1.6702 - y2_output_loss: 5.0968 - y1_output_root_mean_squared_error: 1.2982 - y2_output_root_mean_squared_error: 2.2358 - val_loss: 10.9319 - val_y1_output_loss: 1.0944 - val_y2_output_loss: 9.5242 - val_y1_output_root_mean_squared_error: 1.0494 - val_y2_output_root_mean_squared_error: 3.1354
# Epoch 100/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0386 - y1_output_loss: 0.6685 - y2_output_loss: 2.3476 - y1_output_root_mean_squared_error: 0.8181 - y2_output_root_mean_squared_error: 1.5392 - val_loss: 2.7939 - val_y1_output_loss: 0.7647 - val_y2_output_loss: 2.0175 - val_y1_output_root_mean_squared_error: 0.8815 - val_y2_output_root_mean_squared_error: 1.4202
# Epoch 101/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1355 - y1_output_loss: 0.7241 - y2_output_loss: 2.4061 - y1_output_root_mean_squared_error: 0.8421 - y2_output_root_mean_squared_error: 1.5577 - val_loss: 2.6897 - val_y1_output_loss: 0.8529 - val_y2_output_loss: 1.8487 - val_y1_output_root_mean_squared_error: 0.9251 - val_y2_output_root_mean_squared_error: 1.3542
# Epoch 102/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.2591 - y1_output_loss: 0.9296 - y2_output_loss: 3.2957 - y1_output_root_mean_squared_error: 0.9666 - y2_output_root_mean_squared_error: 1.8234 - val_loss: 2.7958 - val_y1_output_loss: 0.8197 - val_y2_output_loss: 1.9741 - val_y1_output_root_mean_squared_error: 0.9160 - val_y2_output_root_mean_squared_error: 1.3989
# Epoch 103/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0784 - y1_output_loss: 0.7399 - y2_output_loss: 2.3481 - y1_output_root_mean_squared_error: 0.8587 - y2_output_root_mean_squared_error: 1.5301 - val_loss: 3.8068 - val_y1_output_loss: 0.8558 - val_y2_output_loss: 3.0360 - val_y1_output_root_mean_squared_error: 0.9413 - val_y2_output_root_mean_squared_error: 1.7090
# Epoch 104/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.5665 - y1_output_loss: 1.5613 - y2_output_loss: 3.9547 - y1_output_root_mean_squared_error: 1.2546 - y2_output_root_mean_squared_error: 1.9981 - val_loss: 2.3729 - val_y1_output_loss: 0.5275 - val_y2_output_loss: 1.8449 - val_y1_output_root_mean_squared_error: 0.7284 - val_y2_output_root_mean_squared_error: 1.3573
# Epoch 105/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.7090 - y1_output_loss: 0.7597 - y2_output_loss: 2.9516 - y1_output_root_mean_squared_error: 0.8660 - y2_output_root_mean_squared_error: 1.7202 - val_loss: 3.3663 - val_y1_output_loss: 1.2357 - val_y2_output_loss: 2.0936 - val_y1_output_root_mean_squared_error: 1.1028 - val_y2_output_root_mean_squared_error: 1.4663
# Epoch 106/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1922 - y1_output_loss: 0.6995 - y2_output_loss: 2.4814 - y1_output_root_mean_squared_error: 0.8354 - y2_output_root_mean_squared_error: 1.5793 - val_loss: 2.4000 - val_y1_output_loss: 0.5367 - val_y2_output_loss: 1.9150 - val_y1_output_root_mean_squared_error: 0.7390 - val_y2_output_root_mean_squared_error: 1.3616
# Epoch 107/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.0828 - y1_output_loss: 0.6628 - y2_output_loss: 2.4614 - y1_output_root_mean_squared_error: 0.8128 - y2_output_root_mean_squared_error: 1.5563 - val_loss: 3.3723 - val_y1_output_loss: 0.7564 - val_y2_output_loss: 2.5456 - val_y1_output_root_mean_squared_error: 0.8758 - val_y2_output_root_mean_squared_error: 1.6141
# Epoch 108/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3905 - y1_output_loss: 0.7661 - y2_output_loss: 2.6001 - y1_output_root_mean_squared_error: 0.8765 - y2_output_root_mean_squared_error: 1.6193 - val_loss: 2.2051 - val_y1_output_loss: 0.5719 - val_y2_output_loss: 1.6380 - val_y1_output_root_mean_squared_error: 0.7639 - val_y2_output_root_mean_squared_error: 1.2734
# Epoch 109/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7004 - y1_output_loss: 0.5865 - y2_output_loss: 2.0938 - y1_output_root_mean_squared_error: 0.7687 - y2_output_root_mean_squared_error: 1.4524 - val_loss: 2.5047 - val_y1_output_loss: 0.7029 - val_y2_output_loss: 1.8033 - val_y1_output_root_mean_squared_error: 0.8459 - val_y2_output_root_mean_squared_error: 1.3376
# Epoch 110/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.3258 - y1_output_loss: 0.5412 - y2_output_loss: 1.7691 - y1_output_root_mean_squared_error: 0.7373 - y2_output_root_mean_squared_error: 1.3350 - val_loss: 2.5958 - val_y1_output_loss: 0.5856 - val_y2_output_loss: 1.9749 - val_y1_output_root_mean_squared_error: 0.7683 - val_y2_output_root_mean_squared_error: 1.4161
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8920 - y1_output_loss: 0.7065 - y2_output_loss: 2.1606 - y1_output_root_mean_squared_error: 0.8443 - y2_output_root_mean_squared_error: 1.4762 - val_loss: 2.2324 - val_y1_output_loss: 0.5460 - val_y2_output_loss: 1.7101 - val_y1_output_root_mean_squared_error: 0.7434 - val_y2_output_root_mean_squared_error: 1.2961
# Epoch 112/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.2259 - y1_output_loss: 1.1458 - y2_output_loss: 3.2589 - y1_output_root_mean_squared_error: 1.0386 - y2_output_root_mean_squared_error: 1.7740 - val_loss: 8.8321 - val_y1_output_loss: 1.8478 - val_y2_output_loss: 6.7731 - val_y1_output_root_mean_squared_error: 1.3638 - val_y2_output_root_mean_squared_error: 2.6405
# Epoch 113/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7609 - y1_output_loss: 0.6222 - y2_output_loss: 2.1158 - y1_output_root_mean_squared_error: 0.7917 - y2_output_root_mean_squared_error: 1.4608 - val_loss: 2.7439 - val_y1_output_loss: 0.5567 - val_y2_output_loss: 2.1351 - val_y1_output_root_mean_squared_error: 0.7459 - val_y2_output_root_mean_squared_error: 1.4790
# Epoch 114/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6898 - y1_output_loss: 0.6522 - y2_output_loss: 2.0570 - y1_output_root_mean_squared_error: 0.8092 - y2_output_root_mean_squared_error: 1.4265 - val_loss: 4.9523 - val_y1_output_loss: 1.3420 - val_y2_output_loss: 3.6579 - val_y1_output_root_mean_squared_error: 1.1777 - val_y2_output_root_mean_squared_error: 1.8882
# Epoch 115/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9943 - y1_output_loss: 0.5850 - y2_output_loss: 2.4069 - y1_output_root_mean_squared_error: 0.7676 - y2_output_root_mean_squared_error: 1.5508 - val_loss: 3.2309 - val_y1_output_loss: 0.6565 - val_y2_output_loss: 2.5064 - val_y1_output_root_mean_squared_error: 0.8131 - val_y2_output_root_mean_squared_error: 1.6031
# Epoch 116/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.8153 - y1_output_loss: 0.6325 - y2_output_loss: 2.1837 - y1_output_root_mean_squared_error: 0.7982 - y2_output_root_mean_squared_error: 1.4759 - val_loss: 4.0007 - val_y1_output_loss: 0.7227 - val_y2_output_loss: 3.1901 - val_y1_output_root_mean_squared_error: 0.8443 - val_y2_output_root_mean_squared_error: 1.8133
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0395 - y1_output_loss: 0.5710 - y2_output_loss: 2.4750 - y1_output_root_mean_squared_error: 0.7591 - y2_output_root_mean_squared_error: 1.5695 - val_loss: 5.9154 - val_y1_output_loss: 1.1151 - val_y2_output_loss: 4.9182 - val_y1_output_root_mean_squared_error: 1.0732 - val_y2_output_root_mean_squared_error: 2.1826
# Epoch 118/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3794 - y1_output_loss: 0.9351 - y2_output_loss: 2.4240 - y1_output_root_mean_squared_error: 0.9709 - y2_output_root_mean_squared_error: 1.5610 - val_loss: 2.7490 - val_y1_output_loss: 0.9420 - val_y2_output_loss: 1.8177 - val_y1_output_root_mean_squared_error: 0.9748 - val_y2_output_root_mean_squared_error: 1.3412
# Epoch 119/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5332 - y1_output_loss: 0.5392 - y2_output_loss: 1.9812 - y1_output_root_mean_squared_error: 0.7331 - y2_output_root_mean_squared_error: 1.4127 - val_loss: 1.9126 - val_y1_output_loss: 0.4631 - val_y2_output_loss: 1.4393 - val_y1_output_root_mean_squared_error: 0.6871 - val_y2_output_root_mean_squared_error: 1.2002
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0696 - y1_output_loss: 0.7042 - y2_output_loss: 2.3560 - y1_output_root_mean_squared_error: 0.8371 - y2_output_root_mean_squared_error: 1.5391 - val_loss: 2.9129 - val_y1_output_loss: 0.7992 - val_y2_output_loss: 2.1811 - val_y1_output_root_mean_squared_error: 0.9076 - val_y2_output_root_mean_squared_error: 1.4454
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3320 - y1_output_loss: 0.1051 - y2_output_loss: 0.2246 - y1_output_root_mean_squared_error: 0.3256 - y2_output_root_mean_squared_error: 0.4754 - val_loss: 0.9158 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 0.6768 - val_y1_output_root_mean_squared_error: 0.4999 - val_y2_output_root_mean_squared_error: 0.8160
# Epoch 462/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3150 - y1_output_loss: 0.0986 - y2_output_loss: 0.2152 - y1_output_root_mean_squared_error: 0.3137 - y2_output_root_mean_squared_error: 0.4654 - val_loss: 1.0222 - val_y1_output_loss: 0.2401 - val_y2_output_loss: 0.7826 - val_y1_output_root_mean_squared_error: 0.4974 - val_y2_output_root_mean_squared_error: 0.8802
# Epoch 463/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3840 - y1_output_loss: 0.1107 - y2_output_loss: 0.2735 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.5246 - val_loss: 1.0287 - val_y1_output_loss: 0.3719 - val_y2_output_loss: 0.6486 - val_y1_output_root_mean_squared_error: 0.6195 - val_y2_output_root_mean_squared_error: 0.8031
# Epoch 464/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4585 - y1_output_loss: 0.1588 - y2_output_loss: 0.3175 - y1_output_root_mean_squared_error: 0.3889 - y2_output_root_mean_squared_error: 0.5543 - val_loss: 2.5096 - val_y1_output_loss: 0.8388 - val_y2_output_loss: 1.6236 - val_y1_output_root_mean_squared_error: 0.9292 - val_y2_output_root_mean_squared_error: 1.2831
# Epoch 465/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3720 - y1_output_loss: 0.1120 - y2_output_loss: 0.2589 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.5103 - val_loss: 0.9122 - val_y1_output_loss: 0.2588 - val_y2_output_loss: 0.6506 - val_y1_output_root_mean_squared_error: 0.5167 - val_y2_output_root_mean_squared_error: 0.8033
# Epoch 466/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3086 - y1_output_loss: 0.1030 - y2_output_loss: 0.2073 - y1_output_root_mean_squared_error: 0.3193 - y2_output_root_mean_squared_error: 0.4546 - val_loss: 1.0864 - val_y1_output_loss: 0.3406 - val_y2_output_loss: 0.7431 - val_y1_output_root_mean_squared_error: 0.5941 - val_y2_output_root_mean_squared_error: 0.8564
# Epoch 467/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3843 - y1_output_loss: 0.1263 - y2_output_loss: 0.2555 - y1_output_root_mean_squared_error: 0.3569 - y2_output_root_mean_squared_error: 0.5068 - val_loss: 0.8330 - val_y1_output_loss: 0.2241 - val_y2_output_loss: 0.6092 - val_y1_output_root_mean_squared_error: 0.4816 - val_y2_output_root_mean_squared_error: 0.7753
# Epoch 468/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.2985 - y1_output_loss: 0.0947 - y2_output_loss: 0.2017 - y1_output_root_mean_squared_error: 0.3088 - y2_output_root_mean_squared_error: 0.4507 - val_loss: 0.8164 - val_y1_output_loss: 0.2177 - val_y2_output_loss: 0.5994 - val_y1_output_root_mean_squared_error: 0.4746 - val_y2_output_root_mean_squared_error: 0.7689
# Epoch 469/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3605 - y1_output_loss: 0.1067 - y2_output_loss: 0.2544 - y1_output_root_mean_squared_error: 0.3242 - y2_output_root_mean_squared_error: 0.5053 - val_loss: 0.9239 - val_y1_output_loss: 0.2615 - val_y2_output_loss: 0.6669 - val_y1_output_root_mean_squared_error: 0.5188 - val_y2_output_root_mean_squared_error: 0.8092
# Epoch 470/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4022 - y1_output_loss: 0.1296 - y2_output_loss: 0.2706 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.5220 - val_loss: 1.3661 - val_y1_output_loss: 0.2896 - val_y2_output_loss: 1.0647 - val_y1_output_root_mean_squared_error: 0.5478 - val_y2_output_root_mean_squared_error: 1.0324
# Epoch 471/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5212 - y1_output_loss: 0.1263 - y2_output_loss: 0.3917 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.6280 - val_loss: 0.8363 - val_y1_output_loss: 0.2296 - val_y2_output_loss: 0.6082 - val_y1_output_root_mean_squared_error: 0.4879 - val_y2_output_root_mean_squared_error: 0.7735
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3063 - y1_output_loss: 0.1011 - y2_output_loss: 0.2047 - y1_output_root_mean_squared_error: 0.3174 - y2_output_root_mean_squared_error: 0.4534 - val_loss: 0.9372 - val_y1_output_loss: 0.2284 - val_y2_output_loss: 0.7074 - val_y1_output_root_mean_squared_error: 0.4869 - val_y2_output_root_mean_squared_error: 0.8367
# Epoch 473/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3915 - y1_output_loss: 0.1205 - y2_output_loss: 0.2699 - y1_output_root_mean_squared_error: 0.3480 - y2_output_root_mean_squared_error: 0.5200 - val_loss: 0.9040 - val_y1_output_loss: 0.2453 - val_y2_output_loss: 0.6630 - val_y1_output_root_mean_squared_error: 0.5043 - val_y2_output_root_mean_squared_error: 0.8060
# Epoch 474/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5791 - y1_output_loss: 0.1568 - y2_output_loss: 0.4245 - y1_output_root_mean_squared_error: 0.3968 - y2_output_root_mean_squared_error: 0.6493 - val_loss: 1.1161 - val_y1_output_loss: 0.2730 - val_y2_output_loss: 0.8565 - val_y1_output_root_mean_squared_error: 0.5315 - val_y2_output_root_mean_squared_error: 0.9131
# Epoch 475/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3488 - y1_output_loss: 0.1181 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.4830 - val_loss: 1.3385 - val_y1_output_loss: 0.3070 - val_y2_output_loss: 1.0327 - val_y1_output_root_mean_squared_error: 0.5611 - val_y2_output_root_mean_squared_error: 1.0117
# Epoch 476/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4378 - y1_output_loss: 0.1377 - y2_output_loss: 0.3020 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5483 - val_loss: 0.8905 - val_y1_output_loss: 0.3015 - val_y2_output_loss: 0.5865 - val_y1_output_root_mean_squared_error: 0.5588 - val_y2_output_root_mean_squared_error: 0.7604
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3270 - y1_output_loss: 0.1085 - y2_output_loss: 0.2169 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.4672 - val_loss: 0.8823 - val_y1_output_loss: 0.2608 - val_y2_output_loss: 0.6215 - val_y1_output_root_mean_squared_error: 0.5185 - val_y2_output_root_mean_squared_error: 0.7832
# Epoch 478/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3306 - y1_output_loss: 0.1135 - y2_output_loss: 0.2185 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4667 - val_loss: 0.8089 - val_y1_output_loss: 0.2378 - val_y2_output_loss: 0.5745 - val_y1_output_root_mean_squared_error: 0.4962 - val_y2_output_root_mean_squared_error: 0.7502
# Epoch 479/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3601 - y1_output_loss: 0.1027 - y2_output_loss: 0.2567 - y1_output_root_mean_squared_error: 0.3213 - y2_output_root_mean_squared_error: 0.5068 - val_loss: 0.8576 - val_y1_output_loss: 0.2442 - val_y2_output_loss: 0.6101 - val_y1_output_root_mean_squared_error: 0.5027 - val_y2_output_root_mean_squared_error: 0.7778
# Epoch 480/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.2898 - y1_output_loss: 0.0960 - y2_output_loss: 0.1923 - y1_output_root_mean_squared_error: 0.3107 - y2_output_root_mean_squared_error: 0.4396 - val_loss: 0.8260 - val_y1_output_loss: 0.2189 - val_y2_output_loss: 0.6114 - val_y1_output_root_mean_squared_error: 0.4767 - val_y2_output_root_mean_squared_error: 0.7738
# Epoch 481/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3874 - y1_output_loss: 0.1095 - y2_output_loss: 0.2812 - y1_output_root_mean_squared_error: 0.3306 - y2_output_root_mean_squared_error: 0.5274 - val_loss: 0.9656 - val_y1_output_loss: 0.2450 - val_y2_output_loss: 0.7331 - val_y1_output_root_mean_squared_error: 0.5027 - val_y2_output_root_mean_squared_error: 0.8443
# Epoch 482/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3484 - y1_output_loss: 0.1082 - y2_output_loss: 0.2388 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4900 - val_loss: 1.0599 - val_y1_output_loss: 0.2273 - val_y2_output_loss: 0.8315 - val_y1_output_root_mean_squared_error: 0.4852 - val_y2_output_root_mean_squared_error: 0.9080
# Epoch 483/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3406 - y1_output_loss: 0.0960 - y2_output_loss: 0.2434 - y1_output_root_mean_squared_error: 0.3109 - y2_output_root_mean_squared_error: 0.4939 - val_loss: 1.0098 - val_y1_output_loss: 0.2659 - val_y2_output_loss: 0.7519 - val_y1_output_root_mean_squared_error: 0.5241 - val_y2_output_root_mean_squared_error: 0.8574
# Epoch 484/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3073 - y1_output_loss: 0.1028 - y2_output_loss: 0.2035 - y1_output_root_mean_squared_error: 0.3215 - y2_output_root_mean_squared_error: 0.4516 - val_loss: 0.8250 - val_y1_output_loss: 0.2487 - val_y2_output_loss: 0.5802 - val_y1_output_root_mean_squared_error: 0.5076 - val_y2_output_root_mean_squared_error: 0.7532
# Epoch 485/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3924 - y1_output_loss: 0.1259 - y2_output_loss: 0.2643 - y1_output_root_mean_squared_error: 0.3557 - y2_output_root_mean_squared_error: 0.5156 - val_loss: 0.8217 - val_y1_output_loss: 0.2231 - val_y2_output_loss: 0.6057 - val_y1_output_root_mean_squared_error: 0.4800 - val_y2_output_root_mean_squared_error: 0.7690
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4887 - y1_output_loss: 0.1411 - y2_output_loss: 0.3439 - y1_output_root_mean_squared_error: 0.3770 - y2_output_root_mean_squared_error: 0.5887 - val_loss: 1.0133 - val_y1_output_loss: 0.2384 - val_y2_output_loss: 0.7747 - val_y1_output_root_mean_squared_error: 0.4963 - val_y2_output_root_mean_squared_error: 0.8758
# Epoch 487/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3459 - y1_output_loss: 0.1167 - y2_output_loss: 0.2363 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 1.6264 - val_y1_output_loss: 0.3228 - val_y2_output_loss: 1.2793 - val_y1_output_root_mean_squared_error: 0.5777 - val_y2_output_root_mean_squared_error: 1.1369
# Epoch 488/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3671 - y1_output_loss: 0.1236 - y2_output_loss: 0.2423 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.4934 - val_loss: 0.8267 - val_y1_output_loss: 0.2436 - val_y2_output_loss: 0.5885 - val_y1_output_root_mean_squared_error: 0.5016 - val_y2_output_root_mean_squared_error: 0.7583
# Epoch 489/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.2754 - y1_output_loss: 0.0948 - y2_output_loss: 0.1798 - y1_output_root_mean_squared_error: 0.3075 - y2_output_root_mean_squared_error: 0.4253 - val_loss: 0.8629 - val_y1_output_loss: 0.2817 - val_y2_output_loss: 0.5793 - val_y1_output_root_mean_squared_error: 0.5403 - val_y2_output_root_mean_squared_error: 0.7556
# Epoch 490/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4045 - y1_output_loss: 0.1337 - y2_output_loss: 0.2739 - y1_output_root_mean_squared_error: 0.3666 - y2_output_root_mean_squared_error: 0.5197 - val_loss: 1.0809 - val_y1_output_loss: 0.2424 - val_y2_output_loss: 0.8347 - val_y1_output_root_mean_squared_error: 0.5010 - val_y2_output_root_mean_squared_error: 0.9110
# Epoch 491/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3275 - y1_output_loss: 0.1051 - y2_output_loss: 0.2203 - y1_output_root_mean_squared_error: 0.3252 - y2_output_root_mean_squared_error: 0.4709 - val_loss: 0.9057 - val_y1_output_loss: 0.2441 - val_y2_output_loss: 0.6586 - val_y1_output_root_mean_squared_error: 0.5017 - val_y2_output_root_mean_squared_error: 0.8087
# Epoch 492/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3656 - y1_output_loss: 0.1054 - y2_output_loss: 0.2581 - y1_output_root_mean_squared_error: 0.3256 - y2_output_root_mean_squared_error: 0.5095 - val_loss: 1.0665 - val_y1_output_loss: 0.2397 - val_y2_output_loss: 0.8205 - val_y1_output_root_mean_squared_error: 0.4989 - val_y2_output_root_mean_squared_error: 0.9042
# Epoch 493/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3473 - y1_output_loss: 0.1051 - y2_output_loss: 0.2407 - y1_output_root_mean_squared_error: 0.3247 - y2_output_root_mean_squared_error: 0.4918 - val_loss: 1.0214 - val_y1_output_loss: 0.2687 - val_y2_output_loss: 0.7486 - val_y1_output_root_mean_squared_error: 0.5264 - val_y2_output_root_mean_squared_error: 0.8627
# Epoch 494/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3552 - y1_output_loss: 0.1084 - y2_output_loss: 0.2461 - y1_output_root_mean_squared_error: 0.3298 - y2_output_root_mean_squared_error: 0.4964 - val_loss: 0.8685 - val_y1_output_loss: 0.2327 - val_y2_output_loss: 0.6387 - val_y1_output_root_mean_squared_error: 0.4903 - val_y2_output_root_mean_squared_error: 0.7926
# Epoch 495/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4029 - y1_output_loss: 0.1156 - y2_output_loss: 0.2858 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.5360 - val_loss: 0.8905 - val_y1_output_loss: 0.2544 - val_y2_output_loss: 0.6416 - val_y1_output_root_mean_squared_error: 0.5127 - val_y2_output_root_mean_squared_error: 0.7922
# Epoch 496/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3398 - y1_output_loss: 0.1138 - y2_output_loss: 0.2235 - y1_output_root_mean_squared_error: 0.3383 - y2_output_root_mean_squared_error: 0.4747 - val_loss: 0.9224 - val_y1_output_loss: 0.2255 - val_y2_output_loss: 0.6941 - val_y1_output_root_mean_squared_error: 0.4834 - val_y2_output_root_mean_squared_error: 0.8299
# Epoch 497/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3290 - y1_output_loss: 0.1011 - y2_output_loss: 0.2260 - y1_output_root_mean_squared_error: 0.3190 - y2_output_root_mean_squared_error: 0.4767 - val_loss: 0.8225 - val_y1_output_loss: 0.2216 - val_y2_output_loss: 0.6005 - val_y1_output_root_mean_squared_error: 0.4789 - val_y2_output_root_mean_squared_error: 0.7702
# Epoch 498/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2652 - y1_output_loss: 0.0908 - y2_output_loss: 0.1747 - y1_output_root_mean_squared_error: 0.3003 - y2_output_root_mean_squared_error: 0.4184 - val_loss: 0.8344 - val_y1_output_loss: 0.2276 - val_y2_output_loss: 0.6086 - val_y1_output_root_mean_squared_error: 0.4853 - val_y2_output_root_mean_squared_error: 0.7739
# Epoch 499/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3354 - y1_output_loss: 0.1009 - y2_output_loss: 0.2343 - y1_output_root_mean_squared_error: 0.3183 - y2_output_root_mean_squared_error: 0.4838 - val_loss: 0.9328 - val_y1_output_loss: 0.2499 - val_y2_output_loss: 0.6769 - val_y1_output_root_mean_squared_error: 0.5076 - val_y2_output_root_mean_squared_error: 0.8217
# Epoch 500/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3631 - y1_output_loss: 0.1027 - y2_output_loss: 0.2585 - y1_output_root_mean_squared_error: 0.3207 - y2_output_root_mean_squared_error: 0.5102 - val_loss: 0.8419 - val_y1_output_loss: 0.2470 - val_y2_output_loss: 0.5989 - val_y1_output_root_mean_squared_error: 0.5059 - val_y2_output_root_mean_squared_error: 0.7655

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.8419 - y1_output_loss: 0.2583 - y2_output_loss: 0.5819 - y1_output_root_mean_squared_error: 0.5059 - y2_output_root_mean_squared_error: 0.7655
# Loss = 0.8418820306852266, Y1_loss = 0.25833022594451904, Y1_mse = 0.5059313774108887, Y2_loss = 0.5819248557090759, Y2_mse = 0.7654511332511902

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
